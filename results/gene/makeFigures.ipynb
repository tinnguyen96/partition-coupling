# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import describe

# %%
import importlib

# %%
relPath = "../../"

# %%
import sys
sys.path.append(relPath + "modules/")
import compileUtils

# %%
importlib.reload(compileUtils);

# %%
stylefile="../../aistats2022_main.mplstyle"

dirArgs = {"estDir": "temp/ests/", "meetingDir": "temp/couplingChoice/", "getTraces": False}

subDirs = {"CommonRNG": ("CommonRNG/", "green"), "Maximal": ("Maximal/", "red"), "OT":("OTHamming/", "blue")}
dirArgs.update({"subDirs": subDirs})

estArgs = {"trim": 0.01, "ErrorNProcList": np.arange(250, 3000, 250), "IntervalNProcList": np.arange(2000, 22000, 2000)}

funcArgs = {"hType":"LCP", "topKIdx":0}

figMaker = compileUtils.FigureMaker(stylefile, dirArgs, funcArgs, estArgs)
# Out:
# descriptive stats for naive parallel estimates
# 	 DescribeResult(nobs=180000, minmax=(0.31294118, 0.62147601), mean=0.353375972839, variance=0.0014984615969991317, skewness=2.094667595977718, kurtosis=5.948314224304999)
# check if error is within CLT predictions
# 	difference between naive parallel estimates' mean and ground_truth divided by standard error = 358.66
#
# descriptive stats for coupled estimates
# 	 DescribeResult(nobs=180000, minmax=(-65.75865314, 52.27562731), mean=0.3206956326466667, variance=1.1943101813159318, skewness=-5.008112505047304, kurtosis=410.6512656479085)
# check if error is within CLT predictions
# 	difference between coupled estimates' mean and ground_truth divided by standard error = 0.02
#
# ...
# loading meeting time data
# ...
# batching up estimates and computing errors
# ...
# constructing confidence intervals based on batched estimates

# %%
kwargs = {"figsize":(10,2), "constrained_layout":True}
errorYLim = (0, 28)
firstRow = True

figMaker.plotMainFigureRow(errorYLim, firstRow, **kwargs)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
